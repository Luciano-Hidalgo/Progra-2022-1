# %% [markdown]
# <p><img src="https://fing.usach.cl/sites/ingenieria/files/logo-fing.png" alt="LogoUSACH" width="40%" align="right" hspace="10px" vspace="0px"></p>
#
# # GUÍA N°1: EXPRESIONES Y SCRIPTING

# %% [markdown]
# 1.	Construya un programa en Python que, a partir de una cantidad de dinero ingresada por pantalla, indique al usuario el desglose de ese dinero en billetes y monedas nacionales, por ejemplo, si el usuario ingresa $45980, la salida debería ser:
#
#   *	2 billetes de 20.000
#   * 0 billetes de 10.000
#   * 1 billetes de 5.000
#   *	0 billetes de 2.000
#   * 0 billetes de 1.000
#   *	1 monedas de 500
#   *	4 monedas de 100
#   * 1 monedas de 50
#   *	4 monedas de 10
#   *	0 monedas de 5
#   * 0 monedas de 1

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 2.	Construya un programa en Python que, usando solo las herramientas vistas en clase hasta el momento, aproxime un número, por ejemplo, si se ingresa un 3.59, el programa debería responder con un 4, en cambio sí se ingresa un 10.12, el programa debería responder con un 10.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 3.	Construya un programa en Python que reciba como entrada 5 valores, y entregue como resultado el promedio y la desviación estándar de ellos.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 4.	Escriba un programa en Python que pida al usuario una fecha (día y mes por separado) y a partir de ella indique:
#
#   a)	El número de días transcurridos desde el 1 de enero.
#
#   b)	El número de días que faltan para navidad.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 5. Escriba un programa en Python que ingrese un valor entre 1 y 365 e indique a que fecha corresponde ese día, por ejemplo, el día 15, corresponde al 15 de enero, el día 99 corresponde al 9 de abril.

# %%
# Complete aquí con su solución 😁
