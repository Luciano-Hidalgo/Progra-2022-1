# %% [markdown]
# <p><img src="https://fing.usach.cl/sites/ingenieria/files/logo-fing.png" alt="LogoUSACH" width="40%" align="right" hspace="10px" vspace="0px"></p>
#
# # GUÍA N°2: DECISIONES

# %% [markdown]
# 1.	Construya un programa en Python que pida un número e indique si es positivo, negativo o cero.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 2.	Construya un programa en Python que determine si un número es par o no.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 3.	Construya un programa en Python que pida 3 números y los imprima de mayor a menor.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 4.	Construya un programa en Python que pida 4 números y los imprima de menor a mayor.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 5. Carabineros desea generar un sistema de respuesta a emergencias, para ello, desean tener una herramienta que les permita identificar cuál de todos los móviles que tienen despachados en un área es el más cercano al sitio dónde se registra un suceso. Para ello, utilizan un plano y coordenadas xi, yi para identificar el lugar del incidente, del mismo modo, identifican la posición de los móviles en el mapa por las coordenadas xm1, ym1, xm2, ym2, xm3, ym3, ..., xmn, ymn.
#
#   A partir de esta información y sabiendo que la distancia de cada móvil al sitio del suceso puede ser calcula por:
#
#   distancia= √(〖(x_i-x_mn)〗^2+〖(y_i- y_mn)〗^2 )
#
#   Construya un programa que reciba las coordenadas del lugar de los hechos y de los tres móviles más cercanos y le indique al usuario cuál de los tres móviles es el que está a menor distancia del sitio del suceso

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 6.	Construya un programa que convierta valores de longitud/distancia entre una unidad y otra, por ejemplo, el programa solicita un valor de longitud, la unidad en la que está expresada y la unidad a la que se quiere convertir y el sistema realiza las conversiones. Considere para su solución que las unidades de distancia/longitud que debe considerar son:
# •	Metro, Kilómetro, Centímetro, Milímetro, Milla, Legua,  Pulgada, Yarda y Año Luz.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 7.	Construya un programa en Python que solicite una fecha, es decir, el valor del año, mes y día, e indique si dicha fecha existe. Considere para su cálculo que el programa debería reconocer y diferenciar los meses que tienen 28, 30 y 31 días, además de determinar cuándo un año es bisiesto y cuándo no.

# %%
# Complete aquí con su solución 😁
