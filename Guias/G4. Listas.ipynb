# %% [markdown]
# <p><img src="https://fing.usach.cl/sites/ingenieria/files/logo-fing.png" alt="LogoUSACH" width="40%" align="right" hspace="10px" vspace="0px"></p>
#
# # GUÍA N°4: LISTAS

# %% [markdown]
# La siguiente guía presenta 15 ejercicios de listas. Considere que se han marcado explícitamente los ejercicios que han sido usados en una evaluación como **EJERCICIO PEP**.
#
# Para la solución de estos ejercicios usted puede definir una lista como constante al inicio del programa para hacer prueba, sin embargo, en las primeras celdas de este archivo se le entregan dos utilidades para probar con entradas más complejas:
#
# *	`GeneradorListas.py`: El cuál genera listas con la cantidad de elementos y el rango seleccionado por el usuario.
# *	`PedirListas.py`: Qué contiene el código para pedir una lista de números enteros como un conjunto de valores separados por espacios.

# %% [markdown]
# ## PedirListas.py

# %%
# MAGIA NEGRA QUE PIDE UNA LISTA, Y LA TRANSFORMA AUTOMÁTICAMENTE A UNA LISTA DE ENTEROS
lista = list(map(int,input("Ingrese una lista de números enteros, separados por espacio:").split(" ")))

# Se imprime la lista para verificar que tenga lo que queremos
print(lista)

# %%
##########################################################################################
# EXPLICACIÓN
##########################################################################################
# PASO 1: Se solicita una entrada usando input(), esta será un string
lista = input("Ingrese una lista de números enteros, separados por espacio:")

# PRINTS PARA MOSTRAR EL PASO
print('PASO 1:')
print('\t', lista)

# PASO 2: Se utiliza el método .split(" ") para cortar el string por el caracter espacio
# obteniendo así una lista de strings
lista = lista.split(" ")

# PRINTS PARA MOSTRAR EL PASO
print('PASO 2:')
print('\t', lista)

# PASO 3: Se utiliza la función map(), lo que map hace es:
# Aplica la función entregada en el primer parámetro (en este caso int)
# Al objeto del segundo parámetro (en este caso la lista de string)
# Devolviendo un objeto de tipo map, el cuál es útil para iterar pero no para
# almacenar o modificar valores
lista = map(int, lista)

# PRINTS PARA MOSTRAR EL PASO
print('PASO 3:')
print('\t', lista)
# Como vemos, map nos entrega un mensaje de que algo existe en memoria, pero no muestra los valores

# PASO 4: Se realiza la conversión de map a lista, lo que nos permite volver a aplicar
# todas las operaciones de listas sobre la entrada
lista = list(lista)

# PRINTS PARA MOSTRAR EL PASO
print('PASO 4:')
print('\t', lista)

# %% [markdown]
# ### Otras implementaciones de la misma solución.

# %%
# MAGIA NEGRA QUE PIDE UNA LISTA, Y LA TRANSFORMA AUTOMÁTICAMENTE A UNA LISTA DE ENTEROS
lista = list(eval(input("Ingrese una lista de números enteros, separados por coma:"))

# Se imprime la lista para verificar que tenga lo que queremos
print(lista)

##########################################################################################
# EXPLICACIÓN
##########################################################################################
# PASO 1: Se solicita una entrada usando input(), esta será un string
lista = input("Ingrese una lista de números enteros, separados por coma:")

# PRINTS PARA MOSTRAR EL PASO
print('PASO 1:')
print('\t', lista)

# PASO 2: Se utiliza el método eval para transformar el string en una expresión en Python
lista = eval(lista)

# PRINTS PARA MOSTRAR EL PASO
# En este caso, el tipo de dato almacenado es una tupla, lo que es parecido a una lista
# pero es inmutable
print('PASO 2:')
print('\t', lista)

# PASO 3: Se utiliza la función list() para transformar la tupla en lista
lista = list(lista)

# PRINTS PARA MOSTRAR EL PASO
print('PASO 3:')
print('\t', lista)

# %%
# MAGIA NEGRA QUE PIDE UNA LISTA, Y LA TRANSFORMA AUTOMÁTICAMENTE A UNA LISTA DE ENTEROS
lista = eval('['+ ','.join(input('Ingrese una lista de enteros, separados por espacio: ').split(' ')) + ']')

# Se imprime la lista para verificar que tenga lo que queremos
print(lista)

##########################################################################################
# EXPLICACIÓN
##########################################################################################
# PASO 1: Se solicita una entrada usando input(), esta será un string
lista = input("Ingrese una lista de números enteros, separados por espacio:")

# PRINTS PARA MOSTRAR EL PASO
print('PASO 1:')
print('\t', lista)

# PASO 2: Se utiliza el método split para transformar el string en una lista
lista = lista.split(' ')

# PRINTS PARA MOSTRAR EL PASO
print('PASO 2:')
print('\t', lista)

# PASO 3: Se utiliza el método .join() para juntar todos los elementos de la lista en un string separado por comas
# Nótese que el join recibe la lista como argumento y el separador como objeto
lista = ','.join(lista)

# PRINTS PARA MOSTRAR EL PASO
print('PASO 3:')
print('\t', lista)

# PASO 4: Se concatenan los paréntesis al string a fin de formar una lista en Python
lista = '[' + lista + ']'

# PRINTS PARA MOSTRAR EL PASO
print('PASO 4:')
print('\t', lista)

# PASO 5: Se utiliza la función eval() para transformar el string en una expresión válida en Python, en este caso, una lista
lista = eval(lista)

# PRINTS PARA MOSTRAR EL PASO
print('PASO 5:')
print('\t', lista)

# %% [markdown]
# ## GeneradorListas.py

# %%
# Generador de números enteros
from random import randint

# ENTRADA
# Solicito la cantidad de valores para la lista
cantidad = int(input("Ingrese la cantidad de valores que desea: "))

# Solicito el mínimo del rango
minimo = int(input("Ingrese el valor más bajo del rango: "))

# Solicito el máximo del rango
maximo = int(input("Ingrese el valor más alto del rango: "))

# PROCESO
# Declaro la lista vacia
lista = []

# Mientras la lista no tenga la cantidad de elementos
while len(lista) < cantidad :
    #  Se genera un número aleatorio
    numero = randint(minimo, maximo)
    # Se agrega el numero a la lista
    lista.append(numero)
# SALIDA
# Se imprime la lista
print(lista)

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# 1.	Construya un programa en Python que reciba como entrada una lista y un valor e indique si el valor se encuentra o no en la lista.
#
#   Indicación: No use `in` para su implementación.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 2.	Construya un programa en Python que sin usar el método `.count()` haga lo mismo que el método. El método cuenta las veces que aparece un elemento en una lista.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 3.	Construya un programa en Python que reciba una lista de números e indique si la lista está ordenada de menor a mayor o no.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 4.	Construya un programa en Python que reciba como entrada un valor y una posición, e inserte el valor en dicha posición de una lista.
#
#   Indicación: No use `.insert() `para su solución.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 5. Construya un programa en Python que reciba como entrada un elemento y elimine dicho elemento tantas veces como aparezca en una lista. El programa deberá informar la cantidad de elementos que eliminó al finalizar.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 6.	Construya un programa en Python que ordene una lista de valores numéricos de menor a mayor, sin usar métodos, ni funciones para ordenar u obtener mínimos o máximos.
#
#     a)	Realice este programa usando una lista auxiliar para guardar el resultado.
#
#     b)	Realice el programa sin definir una nueva lista.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 7.	**(EJERCICIO PEP)** La dirección meteorológica de Chile está buscando construir un programa para saber cuáles han sido las temperaturas más altas registradas durante el último año en la ciudad de Santiago. Para ello han construido una lista con 365 elementos, indicando las máximas registradas en grados Celsius, desde el 1 de enero de 2015 hasta el 31 de diciembre de 2015. La lista tiene el siguiente formato:
#
#   `TEMPERATURAS_MAXIMAS = [31.5,35.3, 28.2,..., 29.7]`
#
#   Donde la posición 0 representa los 31.5 grados del 1 de enero, la posición 1 la máxima del 2 de enero y así sucesivamente hasta el último elemento que representa la máxima del 31 de diciembre.
#
#     Para apoyar la labor de la dirección meteorológica de Chile, se desea que construya un programa en Python que entregue las n (número ingresado por el usuario) temperaturas más altas del año. Es decir, si n = 15, el programa debería mostrar los 15 valores más altos registrados.
#
#   Considere que a pesar de que la lista TEMPERATURAS_MAXIMAS existe y está definida, su solución debe funcionar para listas de cualquier tamaño y valor, pues se desea aplicar esta solución a otras ciudades y otros períodos de tiempo.
#
#   Restricción: No se pueden utilizar ni funciones ni métodos nativos e importados propios de Python para ordenar, ni para obtener máximos/mínimos valores de un objeto iterable.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 8.	**(EJERCICIO PEP)** Hanamichi es un basquetbolista que desea ser el mejor jugador del mundo. A pesar de su talento natural para anotar, esta temporada ha decidido ser metódico para determinar su rendimiento.
#
#   Para ello, ha registrado los puntos anotados en cada partido en una lista definida como `puntos = [p0, p1,..., pn-1]`. Tras cada partido, revisa si ha roto su récord de máximo y mínimo de puntos anotados hasta el momento de la temporada.
#
#   A Hanamichi le interesa saber cuántas veces en la temporada su rendimiento superar su máximo y baja del mínimo. Asumiendo que el rendimiento del primer partido es la base para dicha medición.
#   Por ejemplo, la temporada pasada Hanamichi registró el rendimiento de sus nueve partidos:
#
#   $\begin{array}
#     \text{Partido N°:}	&	0	 &1 &	2 &	3 &	4 &	5 &	6 &	7 &	8 \\
#     \text{Puntaje:}	& 10 &	5 &	20 &	20 &	4	& 5 &	2 &	25 &	1 \\
#     \text{Récord Máximo:}	& 10 &	10 &	20 &	20 &	20 &	20 & 20 &	25 &	25 \\
#     \text{Récord Mínimo:}	& 10 & 5 & 5 & 5 & 4 & 4 & 2 & 2 & 1 \\
#   \end{array}$
#
#   Esto implica que Hanamichi superó su máximo dos veces, en el partido N°2 y en el N°7, y empeoró su mínimo cuatro veces, en los partidos N°1, N°4, N°6 y N°8.
#
#   Construya un programa en Python que le permita a Hanamichi descubrir cuántas veces supera su máximo y empeora su mínimo, a partir de la lista de partidos, asuma que la lista se encontrará en una variable llamada `"score"`.
#   Por ejemplo, si en esta temporada Hanamichi obtiene la lista `"score"`:
#
#   `[3, 4, 21, 36, 10, 28, 35, 5, 24, 42] `
#
#   El programa debería responderle:
#   ```
#   Hanamichi, superaste tu mejor marca 4 veces durante la temporada
#   y empeoraste tu peor marca 0 veces.
#   ```
#   Considere que el programa debe funcionar para cualquier lista de enteros positivos.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 9.	**(EJERCICIO PEP)** Mr. Oso quiere comprar una pelota de fútbol y una camiseta y cómo el fanático del deporte que es planea gastar el máximo posible para conseguir ambos ítems sin salirse de su presupuesto.
#
#   A fin de conseguir su cometido Mr. Oso desea un programa en Python que reciba el presupuesto con el que actualmente cuenta, los precios de las pelotas de fútbol y los precios de las camisetas a fin de entregarle el valor total que le costará obtener la mejor combinación de ítems.
#
#   Por ejemplo, si Mr. Oso cuenta con un presupuesto de `60.000` pesos y las pelotas de fútbol cuestan = `[5.000, 8.000, 12.000]` y las camisetas cuestan = `[40.000, 50.000. 60.000]`, él podría comprar la camiseta de `40.000` + la pelota de `12.000 = $52.000`, o en cambio la camiseta de `50.000` + la pelota de `8.000 = $58.000`, en este caso la opción que más se acerca a su presupuesto es la segunda, por lo tanto, el programa le informaría de esta opción.
#
#   Construya el programa que Mr. Oso necesita, para ello considere que se solicitan por teclado el presupuesto de Mr. Oso y considere que los precios de pelotas y camisetas están en listas “listaPelotas” y “listaCamisetas” previamente definidas por usted.
#
#   Considere que las entradas siempre contendrán números positivos, sin embargo, en caso de que ningún par pelota, camiseta esté dentro del presupuesto, el programa deberá indicar que se gastará `$0`.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 10.	Construya un programa en Python que, a partir de una lista de valores enteros, elimine los valores repetidos. Considere que, si la lista no tiene elementos repetidos, el programa debería entregar la misma lista.
#
#   Para su solución no se permite:
#   *	Utilizar métodos, ni funciones para ordenar u obtener mínimos y máximos para el desarrollo de la solución.
#   *	El operador in.
#   *	El tipo de dato conjunto (set).
#   Un ejemplo de programa sería el siguiente:
#
#   Ingrese una lista de valores:
#   `2,1,3,4,2,4,3,5,1,4,1,2,4,6,3,3,3 `
#
#   Resultado: `[2,1,3,4,5,6]`

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 11.	Defina dos matrices (listas de listas) de 3x3 números y construya un programa que calcule la multiplicación entre ambas.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 12.	**(EJERCICIO PEP)** Construya un programa en Python que reciba dos listas, A y B, revise si la B es una lista “pseudovalente” de A. Diremos que una lista es pseudovalente de otra, si contiene todos los elementos de la otra al cuadrado, sin importar el orden.
#   Por ejemplo:
#   *	En este caso, las listas A y B son pseudovalentes, pues para cada elemento de A, existe una versión “pseudovalente” en B:
#
#       A = [11, 5, 2, 4, 9, 5, 11]
#       B = [25, 16, 4, 81, 121, 25, 121]
#
#   *	En este caso, las listas A y B no son pseudovalentes, pues existe un elemento en A que no tiene su par “pseudovalente” en B:
#
#       A = [11, 5, 2, 4, 9, 5, 11]
#       B = [16, 4, 81, 121, 25, 121]
#
#   *	En este caso, las listas A y B no son pseudovalentes, pues existe un elemento en B que no tiene su par “pseudovalente” en A:
#
#       A = [11, 5, 2, 4, 9, 5, 11]
#       B = [25, 81, 16, 4, 81, 121, 25, 121]
#
#   El programa deberá informar indicando si la condición para que las listas sean “pseudovalentes” se cumple o no. Basta con un booleano `True` o `False`.
#
#   RESTRICCIÓN: No se pueden utilizar métodos o funciones para obtener máximos, mínimos, u ordenar listas.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 13.	Construya un programa en Python que reciba una lista de listas y entregue la sublista cuya suma de elementos es mayor. Por ejemplo, si la entrada fuera:
# `[[1,2,3], [4,5,6], [10,11,12], [7,8,9]]`
# La sublista con mayor suma es: `[10,11,12]`

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 14.	Construya un programa en Python que entregue el resultado de la intersección de dos listas, por ejemplo, para las listas` A = [1,2,3,4,5,5,4]` y `B = [2, 2, 2, 4, 4, 4, 4, 4, 4, 6, 6, 6, 6]` la intersección sería `[2,4]`.
#
#   Para su solución no puede usar el tipo de dato conjunto (`set`).

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 15.	Construya un programa en Python que entregue el resultado de la unión de dos listas, por ejemplo, para las listas `A = [1,2,3,4,5,5,4]` y `B = [2, 2, 2, 4, 4, 4, 4, 4, 4, 6, 6, 6, 6]` la unión sería `[1,2,3,4,5,6]`.
#
#   Para su solución no puede usar el tipo de dato conjunto (`set`).

# %%
# Complete aquí con su solución 😁
