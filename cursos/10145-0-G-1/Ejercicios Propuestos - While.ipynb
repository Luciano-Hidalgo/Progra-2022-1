# %% [markdown]
# <p><img src="https://fing.usach.cl/sites/ingenieria/files/logo-fing.png" alt="LogoUSACH" width="40%" align="right" hspace="10px" vspace="0px"></p>
#
# # EJERCICIOS PROPUESTOS - CLASE 05 (WHILE)

# %% [markdown]
# El siguiente código calcula la multiplicación de **dos números enteros positivos** como un conjunto de sumas

# %%
# ENTRADA
# Solicito los dos factores
numero1 = input('Ingrese el primer factor: ')
numero2 = input('Ingrese el segundo factor: ')

# Transformo ambos factores a números enteros 
# dado que los recibí como string
numero1 = int(numero1)
numero2 = int(numero2)

# Declaro una variable i para ir contando
# cuantas vueltas doy en el while 
i = 0
# Declaro una variable resultado para
# ir guardando el valor parcial en cada paso
resultado = 0
while i < numero1:
  # Descomentar la línea siguiente si se desea ver el paso a paso
  print('vuelta:', i, ' resultado al entrar:', resultado, 'resultado al salir:', resultado + numero2)
  resultado = resultado + numero2
  i = i + 1

print(numero1,'*',numero2,'=',resultado)
# Out:
# Ingrese el primer factor: 5
# Ingrese el segundo factor: 7
# vuelta: 0  resultado al entrar: 0 resultado al salir: 7
# vuelta: 1  resultado al entrar: 7 resultado al salir: 14
# vuelta: 2  resultado al entrar: 14 resultado al salir: 21
# vuelta: 3  resultado al entrar: 21 resultado al salir: 28
# vuelta: 4  resultado al entrar: 28 resultado al salir: 35
# 5 * 7 = 35

# %% [markdown]
# Sin usar los operadores de multiplicación, división, división entera, ni resto en ningún punto del código, modifique el código entregado para:
# 1. Calcular la división entera y el resto entre dos números enteros positivos.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 2. Calcular la multiplicación entre dos números enteros, considerando ahora la posibilidad de que ahora las entradas podrían considerar valores negativos y positivos.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 3. Calcular la multiplicación entre dos números enteros (positivos o negativos), pero en caso de que por error el usuario ingrese un valor no entero (número de punto flotante) el programa informe del error y pida nuevamente el número

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# <p><img src="https://c.tenor.com/K97FOlIxlDIAAAAd/leo-rey-brigido.gif" alt="LogoUSACH" width="40%" align="right" hspace="10px" vspace="0px"></p>
#
# ## EXTRAS MÁS BRÍGIDOS POR SI QUIERE SEGUIR PRACTICANDO

# %% [markdown]
# 4. Construya un programa que indique si un número entero positivo es primo o no.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 5. Construya un programa que muestre todos los números primos entre 0 y n.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 6. Construya un programa que muestre los primeros *n* números primos.

# %%
# Complete aquí con su solución 😁

# %% [markdown]
# 7. Dado un número entero positivo, construya un programa que muestre la descomposición de este en sus factores primos.
#
#   Por ejemplo:
#
#     100 = 2 * 2 * 5 * 5
#
#     9 = 3 * 3
#
#     13 = 13

# %%
# Complete aquí con su solución 😁
